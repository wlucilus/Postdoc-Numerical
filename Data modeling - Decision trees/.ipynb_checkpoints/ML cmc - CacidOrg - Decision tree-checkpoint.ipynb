# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#read data
#df = pd.read_csv('csvData/articledataDBmerged.csv',  skip_blank_lines=True, skiprows=0, index_col=0)
df = pd.read_csv("csvData/articledataDBmerged4.csv", skiprows=0,skip_blank_lines=True, index_col=0 )
#df = pd.read_csv("git_SeparationJackson/dfwithkhdelta.csv", skiprows=0,skip_blank_lines=True, index_col=0 )
#df = pd.read_csv('csvData/articledataDBextCalcD.dat',  skip_blank_lines=True, skiprows=0)
#df = pd.read_csv('csvData/articledataDBmerged.csv',  skip_blank_lines=True, skiprows=0,  index_col=0)
#df = pd.read_csv('csvData/ModelDBentryTrim.csv', index_col=0, skip_blank_lines=True, skiprows=1)
df
# Out:
#              cid  cid_PM  cid_solvent  cid_acid  CextratantEq (M)  \
# 0     70700400.0     NaN       8182.0     944.0               NaN
# 1     70700400.0     NaN       8182.0     944.0               NaN
# 2     70700400.0     NaN       8182.0     944.0               NaN
# 3     70700400.0     NaN       8182.0     944.0               NaN
# 4     70700400.0     NaN       8182.0     944.0               NaN
# ...          ...     ...          ...       ...               ...
# 8161  70700400.0     NaN       8900.0    1118.0               NaN
# 8162  70700400.0     NaN       8900.0    1118.0               NaN
# 8163  70700400.0     NaN       8900.0    1118.0               NaN
# 8164  70700400.0     NaN       8900.0    1118.0               NaN
# 8165  70700400.0     NaN       8900.0    1118.0               NaN
#
#      ExtractantName  Cextractant (M)  AverageAggregateSize (A)  \
# 0             TODGA             0.10                       NaN
# 1             TODGA             0.10                       NaN
# 2             TODGA             0.10                       NaN
# 3             TODGA             0.10                       NaN
# 4             TODGA             0.10                       NaN
# ...             ...              ...                       ...
# 8161          TODGA             0.02                       NaN
# 8162          TODGA             0.08                       NaN
# 8163          TODGA             0.06                       NaN
# 8164          TODGA             0.04                       NaN
# 8165          TODGA             0.06                       NaN
#
#       Nextractantmol  ExtractantMonomer (%)  ...  Rotatable bond count_acid  \
# 0                NaN                    NaN  ...                        0.0
# 1                NaN                    NaN  ...                        0.0
# 2                NaN                    NaN  ...                        0.0
# 3                NaN                    NaN  ...                        0.0
# 4                NaN                    NaN  ...                        0.0
# ...              ...                    ...  ...                        ...
# 8161             NaN                    NaN  ...                        0.0
# 8162             NaN                    NaN  ...                        0.0
# 8163             NaN                    NaN  ...                        0.0
# 8164             NaN                    NaN  ...                        0.0
# 8165             NaN                    NaN  ...                        0.0
#
#       H bond donor count_acid  H bond acceptor count_acid  Charge_acid  \
# 0                         1.0                         3.0          0.0
# 1                         1.0                         3.0          0.0
# 2                         1.0                         3.0          0.0
# 3                         1.0                         3.0          0.0
# 4                         1.0                         3.0          0.0
# ...                       ...                         ...          ...
# 8161                      2.0                         4.0          0.0
# 8162                      2.0                         4.0          0.0
# 8163                      2.0                         4.0          0.0
# 8164                      2.0                         4.0          0.0
# 8165                      2.0                         4.0          0.0
#
#      Covalent Unit count_acid  TPSA_acid Wiener_acid  Branching Index_acid  \
# 0                         1.0       66.1         9.0                   0.0
# 1                         1.0       66.1         9.0                   0.0
# 2                         1.0       66.1         9.0                   0.0
# 3                         1.0       66.1         9.0                   0.0
# 4                         1.0       66.1         9.0                   0.0
# ...                       ...        ...         ...                   ...
# 8161                      1.0       83.0        16.0                   0.0
# 8162                      1.0       83.0        16.0                   0.0
# 8163                      1.0       83.0        16.0                   0.0
# 8164                      1.0       83.0        16.0                   0.0
# 8165                      1.0       83.0        16.0                   0.0
#
#       Polarity Index_acid  Heterogeneity Index_acid
# 0                4.707928                     1.015
# 1                4.707928                     1.015
# 2                4.707928                     1.015
# 3                4.707928                     1.015
# 4                4.707928                     1.015
# ...                   ...                       ...
# 8161             5.160458                     2.708
# 8162             5.160458                     2.708
# 8163             5.160458                     2.708
# 8164             5.160458                     2.708
# 8165             5.160458                     2.708
#
# [8166 rows x 112 columns]

# %%
dfT = df[df['CacidOrg (M)'].isna() == False]
nodeField = 'Cacid (M)'
threshold= 6
node1 = dfT[dfT[nodeField] < threshold][[nodeField,'CacidOrg (M)']]
node2 = dfT[dfT[nodeField] > threshold][[nodeField,'CacidOrg (M)']]

plt.xlabel(nodeField)
plt.ylabel('CacidOrg (M)')
plt.scatter(node1[nodeField],node1['CacidOrg (M)'], color='red')
plt.scatter(node2[nodeField],node2['CacidOrg (M)'], color='blue')
plt.show()


#entropyN1 = np.sum( node1['CacidOrg (M)']*np.log(node1['CacidOrg (M)']))

# %% [markdown]
# ### Now we should find the important collumns that we are going to use

# %%
#fields that are going to be the input
#there are pre-set to test, use inputFields, yfield to set the desired calculation
i1 = ['Cextractant (M)','Cacid (M)']
i2 = ['Cextractant (M)','Cacid (M)', 'XlogP']
i3 = ['Cextractant (M)','Cacid (M)', 'XlogP', 'Polarity Index']
i4 = ['Cextractant (M)','Cacid (M)', 'Cpm (M)']
i5 = ['Cextractant (M)','Cacid (M)', 'Cpm (M)','Cion (M)']
i6 = ['Cextractant (M)','Cacid (M)', 'Cion (M)']
i7 = ['Cextractant (M)','Cacid (M)', 'Polarity Index','Branching Index']
i8 = ['Cextractant (M)','Cacid (M)', 'Polarity Index','Branching Index','Wiener']
i9 = ['Cextractant (M)','Cacid (M)', 'Polarity Index','Branching Index','Wiener', 'Heterogeneity Index']
i10 = ['Cextractant (M)','Cacid (M)', 'Polarity Index','Branching Index', 'Heterogeneity Index']
i11 = ['Cextractant (M)','Cacid (M)','XlogP', 'Polarity Index','Branching Index', 'Heterogeneity Index']
i12 = ['Cextractant (M)','Cacid (M)','XlogP', 'Polarity Index','Branching Index', 'Heterogeneity Index', 'Temp (K)']
i13 = ['Cextractant (M)','Cacid (M)','XlogP', 'Polarity Index','Branching Index', 'Heterogeneity Index', 'Temp (K)','Cpm (M)']
i14 = ['Cextractant (M)','Cacid (M)','XlogP', 'Polarity Index','Branching Index', 'Heterogeneity Index','Cpm (M)']
i15 = ['Cextractant (M)', 'intensity', 'Cacid (M)','Molecular Weight', 'XlogP',
       'Rotatable bond count', 'H bond donor count', 'H bond acceptor count',
       'Charge', 'Covalent Unit count', 'TPSA', 'Wiener', 'Branching Index',
       'Polarity Index', 'Heterogeneity Index']

i16 = ['Cextractant (M)', 'Rg', 'has acid?']
i17 = ['Cextractant (M)', 'Cacid (M)', 'Cpm (M)']
i18 = ['Cextractant (M)', 'Cacid (M)', 'Branching Index']
i19= ['Cextractant (M)', 'Rg', 'Temp (K)']
i20 = ['Cextractant (M)', 'Cacid (M)', 'Cion (M)', 'XlogP']
i21 = ['Cacid (M)', 'Cpm (M)', 'Polarity Index', 'Heterogeneity Index']
i22= ['Cextractant (M)', 'Cacid (M)', 'Cpm (M)', 'Branching Index']
#, ('Cextractant (M)', 'Cacid (M)', 'Cpm (M)', 'Polarity Index'), ('Cextractant (M)', 'Cacid (M)', 'Cpm (M)', 'Heterogeneity Index')
i23 = ['Cextractant (M)', 'Rg', 'Temp (K)', 'Molecular Weight']
i24 = ['Cextractant (M)', 'Cacid (M)', 'Cpm (M)', 'Charge', 'Covalent Unit count', 'TPSA', 'Wiener', 'Branching Index', 'Polarity Index', 'Heterogeneity Index']
i25 = ['Cextractant (M)','Cacid (M)','Cpm (M)','XlogP']
i26 = ['Cextractant (M)', 'Cacid (M)', 'H bond acceptor count', 'Polarity Index', 'Heterogeneity Index']

i27= ['Cextractant (M)', 'Cacid (M)', 'Cpm (M)','XlogP','H bond acceptor count', 'Polarity Index', 'Heterogeneity Index', 'Branching Index']

t1 = ['Cextractant (M)','Cacid (M)']
t2 = ['Cextractant (M)','Cacid (M)', 'XlogP']
t3 = ['Cextractant (M)','Cacid (M)', 'Polarity Index']
t4 = ['Cextractant (M)','Cacid (M)', 'Branching Index']
t5 = ['Cextractant (M)','Cacid (M)', 'Heterogeneity Index']
t6 = ['Cextractant (M)','Cacid (M)', 'Wiener']
t7 = ['Cextractant (M)','Cacid (M)','XlogP', 'Polarity Index', 'Branching Index', 'Heterogeneity Index', 'Wiener']#, 'Kh', 'DeltaG (kJ/mol)']

o1 = ['CacidOrg (M)']
o2 = ['CionOrg (M)']
o3 = ['D(acid)']
o4 = ['D(ion)']
o5 = ['Rg']
o6 = ['ExtractantMonomer (%)']
o7 = ['AverageAggregateSize (A)']

inputField = t7
outputFields = o1

# %%
#extra condition to separate the database
dfSize=df[ (df['has PM?'] == 0) & (df['Third phase'] == 0)]
#dfSize = df

#Cleaning the null and NaN fields
feature = dfSize[inputField+outputFields].copy()
feature = feature.dropna()
feature = feature.drop_duplicates()
feature = feature.reset_index(drop=True)  ## this line is important, otherwise the indexes will be wierd
feature
# Out:
#       Cextractant (M)  Cacid (M)  XlogP  Polarity Index  Branching Index  \
# 0              0.2010   1.000000   17.1        3.722409            144.0
# 1              0.1000   1.000000   17.1        3.722409            144.0
# 2              0.0500   1.000000   17.1        3.722409            144.0
# 3              0.2520   1.000000   17.1        3.722409            144.0
# 4              0.2000   2.987212   11.6        3.722409            360.0
# ...               ...        ...    ...             ...              ...
# 1972           1.4719   8.598368    2.9        6.211799             30.0
# 1973           1.4719   7.756384    2.9        6.211799             30.0
# 1974           1.4719   7.201227    2.9        6.211799             30.0
# 1975           1.4719   6.317099    2.9        6.211799             30.0
# 1976           1.4719   4.639518    2.9        6.211799             30.0
#
#       Heterogeneity Index   Wiener  CacidOrg (M)
# 0                   8.416  13036.0      0.019000
# 1                   8.416  13036.0      0.011000
# 2                   8.416  13036.0      0.008000
# 3                   8.416  13036.0      0.025000
# 4                   8.774   6572.0      0.175497
# ...                   ...      ...           ...
# 1972                8.888    616.0      0.732297
# 1973                8.888    616.0      0.515313
# 1974                8.888    616.0      0.406584
# 1975                8.888    616.0      0.281385
# 1976                8.888    616.0      0.112732
#
# [1977 rows x 8 columns]

# %% [markdown]
# ## Decision tree classifier/prediction?

# %%
#define the category values
y = feature['CacidOrg (M)'].values
y

feature = feature.drop('CacidOrg (M)', axis=1)
feature_list = list(feature.columns)
#feature_list
X = np.array(feature)
#X[0:5,::]

# %%
#split the data set
from sklearn.model_selection import train_test_split
X_trainset, X_testset, y_trainset, y_testset = train_test_split(X, y, test_size=0.30, random_state=3)
#create the classifier
from sklearn.tree import DecisionTreeRegressor
import sklearn.tree as tree
from sklearn import metrics

myTree = DecisionTreeRegressor(max_depth=8) #use 2^max_depth = number of possible branches...
myTree # it shows the default parameters

#fit the train set...
myTree.fit(X_trainset,y_trainset)
#now that it is trained we can make some predictions
predTree = myTree.predict(X_testset)
predictionsTrain = myTree.predict(X_trainset)
#print (predTree[0:10])
#print (y_testset[0:10])

plt.xlabel("Test set rows")
plt.ylabel("Test set")
plt.plot(y_testset, marker='+', label='Testset (true values)')
plt.plot(predTree, marker = 'o', label='predictions')
plt.legend()
plt.show()

r2 = metrics.r2_score(y_testset,predTree)
rmse = np.sqrt(metrics.mean_squared_error(y_testset, predTree))
mae = np.abs(np.mean(y_testset-predTree))
#now use some metrics to see how good are the predictions
print("DecisionTrees's R2: ", r2)
print("Root mean square error:", rmse)
print('Mean Absolute Error:',mae , 'M')

plt.xlabel("true CacidOrg (M)")
plt.ylabel("true CacidOrg (M)"
plt.scatter(y_testset, predTree, label=f'R²: {r2:.3f}, RMSE: {rmse:.3f}, MAE: {mae:.3f}')
plt.xlabel('True Values')
plt.ylabel('Predicted Values')
plt.title('Model Performance')
plt.legend()
plt.show()
plt.plot(y_testset, y_testset)
plt.title('Test set: '+f"{100*len(y_testset)/(len(y_testset)+len(y_trainset)):.1f}"+'% of '+str(len(y))+' points)')


plt.show()
#_______tranning information
plt.xlabel("Train set rows")
plt.ylabel("Train set")
plt.plot(y_trainset, marker='+')
plt.plot(predictionsTrain, marker = 'o')
#plt.legend()
plt.show()

plt.xlabel("CacidOrg (M)")
plt.ylabel("CacidOrg (M)")
plt.scatter(y_trainset, predictionsTrain)
plt.plot(y_trainset, y_trainset)
plt.title('Train set: '+f"{100*len(y_trainset)/(len(y_testset)+len(y_trainset)):.1f}"+'% of '+str(len(y))+' points)')
plt.show()

#now use some metrics to see how good are the predictions
print("DecisionTrees's R2: ", metrics.r2_score(y_trainset,predictionsTrain))
print("Root mean square error:", np.sqrt(metrics.mean_squared_error(y_trainset, predictionsTrain)))
# Print out the mean absolute error (mae)
print('Mean Absolute Error:', abs(np.mean(y_trainset-predictionsTrain)), 'M')
# Out:
#   File "C:\Users\lucil\AppData\Local\Temp\ipykernel_12996\1621999617.py", line 37
#     plt.scatter(y_testset, predTree, label=f'R2:{r2} RMSE:{rmse} MAE:{mae}')
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# > I can get 0.88/0.94 for CacidOrg, based on i14 o1, for data with no PM...

# %%
#Look what are the experimental configuration of the points that deviate a lot.
dfDeviation = pd.DataFrame( X_testset[(y_testset-predTree)>0.05] , columns= feature_list)
dfDeviation.sort_values(by=['Cextractant (M)','Cacid (M)'])
# Out:
#     Cextractant (M)  Cacid (M)  XlogP  Polarity Index  Branching Index  \
# 32          0.10000   3.309446   12.2        3.722409            220.0
# 18          0.10000   6.944291   12.8        3.722409            120.0
# 1           0.10000   6.946114   12.8        3.722409            120.0
# 16          0.10000   6.947655   12.8        3.722409            120.0
# 8           0.10000   6.949928   12.8        3.722409            120.0
# 22          0.10000   6.953700   12.8        3.722409            120.0
# 30          0.15156   1.000000   12.8        3.722409            120.0
# 43          0.15271   1.000000   12.8        3.722409            120.0
# 38          0.16703   1.000000   12.8        3.722409            120.0
# 45          0.19790   3.900000   12.8        3.722409            120.0
# 17          0.20000   2.033000   12.8        3.722409            120.0
# 2           0.20000   2.083610   12.8        3.722409            120.0
# 3           0.20000   2.261087   12.8        3.722409            120.0
# 4           0.20000   2.966849   12.8        3.722409            120.0
# 42          0.20000   4.874744   12.8        3.722409            120.0
# 5           0.20000   4.951867   12.8        3.722409            120.0
# 23          0.20000   4.980800   12.8        3.722409            120.0
# 15          0.20000   4.981004   17.1        3.722409            144.0
# 25          0.20000   6.739000   12.8        3.722409            120.0
# 12          0.30000   6.968500   12.8        3.722409            120.0
# 27          0.34880   3.900000   12.8        3.722409            120.0
# 19          0.40000   5.872000   12.8        3.722409            120.0
# 44          0.49790   3.900000   12.8        3.722409            120.0
# 39          0.49870   3.900000   12.8        3.722409            120.0
# 14          0.50000   4.881800   12.8        3.722409            120.0
# 11          0.50000   6.968500   12.8        3.722409            120.0
# 40          0.60030   3.900000   12.8        3.722409            120.0
# 28          0.90000   3.000000    8.8        3.552523            132.0
# 37          0.98420   4.600000   11.6        3.722409            360.0
# 21          1.10000   7.983800    2.9        6.211799             30.0
# 20          1.10000   8.003200    2.9        6.211799             30.0
# 36          1.10000  11.982100    2.9        6.211799             30.0
# 34          1.39530   3.100000    2.9        6.211799             30.0
# 41          1.39790   3.100000    2.9        6.211799             30.0
# 29          1.47190   5.188633    2.9        6.211799             30.0
# 31          1.47190   5.197300    2.9        6.211799             30.0
# 24          1.47190   7.201227    2.9        6.211799             30.0
# 9           2.20790   4.050545    2.9        6.211799             30.0
# 6           2.20790   4.939738    2.9        6.211799             30.0
# 13          2.20790   5.019400    2.9        6.211799             30.0
# 35          2.20790   5.040433    2.9        6.211799             30.0
# 0           2.20790   5.047600    2.9        6.211799             30.0
# 33          2.20790   5.619367    2.9        6.211799             30.0
# 10          2.20790   6.221455    2.9        6.211799             30.0
# 46          2.20790   6.341767    2.9        6.211799             30.0
# 7           2.20790   6.567800    2.9        6.211799             30.0
# 26          2.20790   6.572000    2.9        6.211799             30.0
#
#     Heterogeneity Index   Wiener
# 32                8.595   7116.0
# 18                8.416   7660.0
# 1                 8.416   7660.0
# 16                8.416   7660.0
# 8                 8.416   7660.0
# 22                8.416   7660.0
# 30                8.416   7660.0
# 43                8.416   7660.0
# 38                8.416   7660.0
# 45                8.416   7660.0
# 17                8.416   7660.0
# 2                 8.416   7660.0
# 3                 8.416   7660.0
# 4                 8.416   7660.0
# 42                8.416   7660.0
# 5                 8.416   7660.0
# 23                8.416   7660.0
# 15                8.416  13036.0
# 25                8.416   7660.0
# 12                8.416   7660.0
# 27                8.416   7660.0
# 19                8.416   7660.0
# 44                8.416   7660.0
# 39                8.416   7660.0
# 14                8.416   7660.0
# 11                8.416   7660.0
# 40                8.416   7660.0
# 28                8.593   4425.0
# 37                8.774   6572.0
# 21                8.888    616.0
# 20                8.888    616.0
# 36                8.888    616.0
# 34                8.888    616.0
# 41                8.888    616.0
# 29                8.888    616.0
# 31                8.888    616.0
# 24                8.888    616.0
# 9                 8.888    616.0
# 6                 8.888    616.0
# 13                8.888    616.0
# 35                8.888    616.0
# 0                 8.888    616.0
# 33                8.888    616.0
# 10                8.888    616.0
# 46                8.888    616.0
# 7                 8.888    616.0
# 26                8.888    616.0

# %%
#Look what are the experimental configuration of the points that deviate a lot.
#lista =  feature_list+list([y])+list(['ypred','error'])
#reconstructedPrediction = pd.DataFrame([X_test,y_test, ypred], columns=lista)
#reconstructedPrediction = pd.DataFrame(data=np.column_stack((X_testset, y_testset, predTree, y_testset-predTree)), columns=lista)
#reconstructedPrediction

# %%
text_representation = tree.export_text(myTree)
#print(text_representation)
##recover original names of variables...
tnew = text_representation  #.replace("feature_0","has Acid?")

#names = ['ExtractantName', 'SolventName', 'AcidName',
#       'has acid?', 'Cacid (M)', 'CacidOrg (M)', 'ExtractionFactor',
#       'has ions?', 'xlogp', 'molecular_weight', 'h_bond_donor_count']

print(feature_list)

for i,name in enumerate(feature_list):
    tnew = tnew.replace('feature_'+str(i), name)

print(tnew)
outputTree = open('tree.dat','w+')
outputTree.write(tnew)
outputTree.close()
# Out:
# ['Cextractant (M)', 'Cacid (M)', 'XlogP', 'Polarity Index', 'Branching Index', 'Heterogeneity Index', 'Wiener']
# |--- Cacid (M) <= 2.97
# |   |--- Cacid (M) <= 1.95
# |   |   |--- Cacid (M) <= 0.74
# |   |   |   |--- Cacid (M) <= 0.47
# |   |   |   |   |--- Branching Index <= 126.00
# |   |   |   |   |   |--- Cextractant (M) <= 0.15
# |   |   |   |   |   |   |--- Cacid (M) <= 0.16
# |   |   |   |   |   |   |   |--- Cacid (M) <= 0.10
# |   |   |   |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |   |   |   |--- Cacid (M) >  0.10
# |   |   |   |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |   |   |--- Cacid (M) >  0.16
# |   |   |   |   |   |   |   |--- Cacid (M) <= 0.21
# |   |   |   |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |   |   |   |--- Cacid (M) >  0.21
# |   |   |   |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |   |--- Cextractant (M) >  0.15
# |   |   |   |   |   |   |--- Cextractant (M) <= 0.25
# |   |   |   |   |   |   |   |--- Cacid (M) <= 0.09
# |   |   |   |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |   |   |   |--- Cacid (M) >  0.09
# |   |   |   |   |   |   |   |   |--- value: [0.02]
# |   |   |   |   |   |   |--- Cextractant (M) >  0.25
# |   |   |   |   |   |   |   |--- Cextractant (M) <= 1.29
# |   |   |   |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |   |   |   |--- Cextractant (M) >  1.29
# |   |   |   |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |--- Branching Index >  126.00
# |   |   |   |   |   |--- Cextractant (M) <= 0.25
# |   |   |   |   |   |   |--- Cacid (M) <= 0.21
# |   |   |   |   |   |   |   |--- Cacid (M) <= 0.10
# |   |   |   |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |   |   |   |--- Cacid (M) >  0.10
# |   |   |   |   |   |   |   |   |--- value: [0.01]
# |   |   |   |   |   |   |--- Cacid (M) >  0.21
# |   |   |   |   |   |   |   |--- Cacid (M) <= 0.36
# |   |   |   |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |   |   |   |--- Cacid (M) >  0.36
# |   |   |   |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |   |--- Cextractant (M) >  0.25
# |   |   |   |   |   |   |--- Branching Index <= 246.00
# |   |   |   |   |   |   |   |--- Cacid (M) <= 0.26
# |   |   |   |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |   |   |   |--- Cacid (M) >  0.26
# |   |   |   |   |   |   |   |   |--- value: [0.02]
# |   |   |   |   |   |   |--- Branching Index >  246.00
# |   |   |   |   |   |   |   |--- Cextractant (M) <= 0.45
# |   |   |   |   |   |   |   |   |--- value: [0.01]
# |   |   |   |   |   |   |   |--- Cextractant (M) >  0.45
# |   |   |   |   |   |   |   |   |--- value: [0.02]
# |   |   |   |--- Cacid (M) >  0.47
# |   |   |   |   |--- Polarity Index <= 3.64
# |   |   |   |   |   |--- Cextractant (M) <= 0.88
# |   |   |   |   |   |   |--- Cextractant (M) <= 0.70
# |   |   |   |   |   |   |   |--- Cacid (M) <= 0.49
# |   |   |   |   |   |   |   |   |--- value: [0.02]
# |   |   |   |   |   |   |   |--- Cacid (M) >  0.49
# |   |   |   |   |   |   |   |   |--- value: [0.03]
# |   |   |   |   |   |   |--- Cextractant (M) >  0.70
# |   |   |   |   |   |   |   |--- value: [0.03]
# |   |   |   |   |   |--- Cextractant (M) >  0.88
# |   |   |   |   |   |   |--- Cacid (M) <= 0.59
# |   |   |   |   |   |   |   |--- value: [0.05]
# |   |   |   |   |   |   |--- Cacid (M) >  0.59
# |   |   |   |   |   |   |   |--- value: [0.08]
# |   |   |   |   |--- Polarity Index >  3.64
# |   |   |   |   |   |--- Heterogeneity Index <= 8.68
# |   |   |   |   |   |   |--- Cextractant (M) <= 0.17
# |   |   |   |   |   |   |   |--- Cacid (M) <= 0.52
# |   |   |   |   |   |   |   |   |--- value: [0.01]
# |   |   |   |   |   |   |   |--- Cacid (M) >  0.52
# |   |   |   |   |   |   |   |   |--- value: [0.01]
# |   |   |   |   |   |   |--- Cextractant (M) >  0.17
# |   |   |   |   |   |   |   |--- Cacid (M) <= 0.48
# |   |   |   |   |   |   |   |   |--- value: [0.01]
# |   |   |   |   |   |   |   |--- Cacid (M) >  0.48
# |   |   |   |   |   |   |   |   |--- value: [0.02]
# |   |   |   |   |   |--- Heterogeneity Index >  8.68
# |   |   |   |   |   |   |--- Cacid (M) <= 0.53
# |   |   |   |   |   |   |   |--- Heterogeneity Index <= 8.83
# |   |   |   |   |   |   |   |   |--- value: [0.02]
# |   |   |   |   |   |   |   |--- Heterogeneity Index >  8.83
# |   |   |   |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |   |   |--- Cacid (M) >  0.53
# |   |   |   |   |   |   |   |--- Polarity Index <= 4.97
# |   |   |   |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |   |   |   |--- Polarity Index >  4.97
# |   |   |   |   |   |   |   |   |--- value: [0.00]
# |   |   |--- Cacid (M) >  0.74
# |   |   |   |--- Cextractant (M) <= 0.12
# |   |   |   |   |--- Cextractant (M) <= 0.08
# |   |   |   |   |   |--- Cextractant (M) <= 0.03
# |   |   |   |   |   |   |--- Cextractant (M) <= 0.01
# |   |   |   |   |   |   |   |--- Cextractant (M) <= 0.01
# |   |   |   |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |   |   |   |--- Cextractant (M) >  0.01
# |   |   |   |   |   |   |   |   |--- value: [0.01]
# |   |   |   |   |   |   |--- Cextractant (M) >  0.01
# |   |   |   |   |   |   |   |--- Cextractant (M) <= 0.01
# |   |   |   |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |   |   |   |--- Cextractant (M) >  0.01
# |   |   |   |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |   |--- Cextractant (M) >  0.03
# |   |   |   |   |   |   |--- Cextractant (M) <= 0.05
# |   |   |   |   |   |   |   |--- XlogP <= 12.50
# |   |   |   |   |   |   |   |   |--- value: [0.01]
# |   |   |   |   |   |   |   |--- XlogP >  12.50
# |   |   |   |   |   |   |   |   |--- value: [0.04]
# |   |   |   |   |   |   |--- Cextractant (M) >  0.05
# |   |   |   |   |   |   |   |--- Cacid (M) <= 1.44
# |   |   |   |   |   |   |   |   |--- value: [0.01]
# |   |   |   |   |   |   |   |--- Cacid (M) >  1.44
# |   |   |   |   |   |   |   |   |--- value: [0.02]
# |   |   |   |   |--- Cextractant (M) >  0.08
# |   |   |   |   |   |--- Cextractant (M) <= 0.10
# |   |   |   |   |   |   |--- Cextractant (M) <= 0.09
# |   |   |   |   |   |   |   |--- value: [0.07]
# |   |   |   |   |   |   |--- Cextractant (M) >  0.09
# |   |   |   |   |   |   |   |--- value: [0.08]
# |   |   |   |   |   |--- Cextractant (M) >  0.10
# |   |   |   |   |   |   |--- Cacid (M) <= 1.63
# |   |   |   |   |   |   |   |--- Cextractant (M) <= 0.11
# |   |   |   |   |   |   |   |   |--- value: [0.02]
# |   |   |   |   |   |   |   |--- Cextractant (M) >  0.11
# |   |   |   |   |   |   |   |   |--- value: [0.03]
# |   |   |   |   |   |   |--- Cacid (M) >  1.63
# |   |   |   |   |   |   |   |--- value: [0.05]
# |   |   |   |--- Cextractant (M) >  0.12
# |   |   |   |   |--- Cextractant (M) <= 1.29
# |   |   |   |   |   |--- Cextractant (M) <= 0.74
# |   |   |   |   |   |   |--- XlogP <= 6.65
# |   |   |   |   |   |   |   |--- Polarity Index <= 4.26
# |   |   |   |   |   |   |   |   |--- value: [0.01]
# |   |   |   |   |   |   |   |--- Polarity Index >  4.26
# |   |   |   |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |   |   |--- XlogP >  6.65
# |   |   |   |   |   |   |   |--- Cextractant (M) <= 0.25
# |   |   |   |   |   |   |   |   |--- value: [0.07]
# |   |   |   |   |   |   |   |--- Cextractant (M) >  0.25
# |   |   |   |   |   |   |   |   |--- value: [0.10]
# |   |   |   |   |   |--- Cextractant (M) >  0.74
# |   |   |   |   |   |   |--- Cacid (M) <= 1.15
# |   |   |   |   |   |   |   |--- Cacid (M) <= 0.97
# |   |   |   |   |   |   |   |   |--- value: [0.11]
# |   |   |   |   |   |   |   |--- Cacid (M) >  0.97
# |   |   |   |   |   |   |   |   |--- value: [0.14]
# |   |   |   |   |   |   |--- Cacid (M) >  1.15
# |   |   |   |   |   |   |   |--- Cextractant (M) <= 0.88
# |   |   |   |   |   |   |   |   |--- value: [0.15]
# |   |   |   |   |   |   |   |--- Cextractant (M) >  0.88
# |   |   |   |   |   |   |   |   |--- value: [0.23]
# |   |   |   |   |--- Cextractant (M) >  1.29
# |   |   |   |   |   |--- Cacid (M) <= 1.28
# |   |   |   |   |   |   |--- Cacid (M) <= 0.77
# |   |   |   |   |   |   |   |--- Cacid (M) <= 0.76
# |   |   |   |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |   |   |   |--- Cacid (M) >  0.76
# |   |   |   |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |   |   |--- Cacid (M) >  0.77
# |   |   |   |   |   |   |   |--- Cacid (M) <= 0.79
# |   |   |   |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |   |   |   |--- Cacid (M) >  0.79
# |   |   |   |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |   |--- Cacid (M) >  1.28
# |   |   |   |   |   |   |--- Cacid (M) <= 1.92
# |   |   |   |   |   |   |   |--- Cextractant (M) <= 1.84
# |   |   |   |   |   |   |   |   |--- value: [0.01]
# |   |   |   |   |   |   |   |--- Cextractant (M) >  1.84
# |   |   |   |   |   |   |   |   |--- value: [0.01]
# |   |   |   |   |   |   |--- Cacid (M) >  1.92
# |   |   |   |   |   |   |   |--- value: [0.02]
# |   |--- Cacid (M) >  1.95
# |   |   |--- Polarity Index <= 3.64
# |   |   |   |--- Cacid (M) <= 2.58
# |   |   |   |   |--- Wiener <= 2890.50
# |   |   |   |   |   |--- Branching Index <= 28.00
# |   |   |   |   |   |   |--- value: [0.02]
# |   |   |   |   |   |--- Branching Index >  28.00
# |   |   |   |   |   |   |--- value: [0.14]
# |   |   |   |   |--- Wiener >  2890.50
# |   |   |   |   |   |--- Cextractant (M) <= 0.88
# |   |   |   |   |   |   |--- Cacid (M) <= 2.21
# |   |   |   |   |   |   |   |--- value: [0.27]
# |   |   |   |   |   |   |--- Cacid (M) >  2.21
# |   |   |   |   |   |   |   |--- value: [0.31]
# |   |   |   |   |   |--- Cextractant (M) >  0.88
# |   |   |   |   |   |   |--- value: [0.36]
# |   |   |   |--- Cacid (M) >  2.58
# |   |   |   |   |--- Cacid (M) <= 2.81
# |   |   |   |   |   |--- value: [2.84]
# |   |   |   |   |--- Cacid (M) >  2.81
# |   |   |   |   |   |--- Heterogeneity Index <= 6.36
# |   |   |   |   |   |   |--- value: [0.02]
# |   |   |   |   |   |--- Heterogeneity Index >  6.36
# |   |   |   |   |   |   |--- Cextractant (M) <= 0.62
# |   |   |   |   |   |   |   |--- value: [0.30]
# |   |   |   |   |   |   |--- Cextractant (M) >  0.62
# |   |   |   |   |   |   |   |--- Cextractant (M) <= 0.88
# |   |   |   |   |   |   |   |   |--- value: [0.46]
# |   |   |   |   |   |   |   |--- Cextractant (M) >  0.88
# |   |   |   |   |   |   |   |   |--- value: [0.57]
# |   |   |--- Polarity Index >  3.64
# |   |   |   |--- Heterogeneity Index <= 8.51
# |   |   |   |   |--- Cextractant (M) <= 0.18
# |   |   |   |   |   |--- Cacid (M) <= 2.15
# |   |   |   |   |   |   |--- Cextractant (M) <= 0.12
# |   |   |   |   |   |   |   |--- Cacid (M) <= 2.01
# |   |   |   |   |   |   |   |   |--- value: [0.06]
# |   |   |   |   |   |   |   |--- Cacid (M) >  2.01
# |   |   |   |   |   |   |   |   |--- value: [0.07]
# |   |   |   |   |   |   |--- Cextractant (M) >  0.12
# |   |   |   |   |   |   |   |--- Cextractant (M) <= 0.15
# |   |   |   |   |   |   |   |   |--- value: [0.08]
# |   |   |   |   |   |   |   |--- Cextractant (M) >  0.15
# |   |   |   |   |   |   |   |   |--- value: [0.09]
# |   |   |   |   |   |--- Cacid (M) >  2.15
# |   |   |   |   |   |   |--- Cextractant (M) <= 0.13
# |   |   |   |   |   |   |   |--- Cextractant (M) <= 0.09
# |   |   |   |   |   |   |   |   |--- value: [0.08]
# |   |   |   |   |   |   |   |--- Cextractant (M) >  0.09
# |   |   |   |   |   |   |   |   |--- value: [0.10]
# |   |   |   |   |   |   |--- Cextractant (M) >  0.13
# |   |   |   |   |   |   |   |--- Cacid (M) <= 2.51
# |   |   |   |   |   |   |   |   |--- value: [0.09]
# |   |   |   |   |   |   |   |--- Cacid (M) >  2.51
# |   |   |   |   |   |   |   |   |--- value: [0.14]
# |   |   |   |   |--- Cextractant (M) >  0.18
# |   |   |   |   |   |--- Cextractant (M) <= 0.30
# |   |   |   |   |   |   |--- Cacid (M) <= 2.53
# |   |   |   |   |   |   |   |--- Cextractant (M) <= 0.23
# |   |   |   |   |   |   |   |   |--- value: [0.12]
# |   |   |   |   |   |   |   |--- Cextractant (M) >  0.23
# |   |   |   |   |   |   |   |   |--- value: [0.16]
# |   |   |   |   |   |   |--- Cacid (M) >  2.53
# |   |   |   |   |   |   |   |--- Cextractant (M) <= 0.23
# |   |   |   |   |   |   |   |   |--- value: [0.18]
# |   |   |   |   |   |   |   |--- Cextractant (M) >  0.23
# |   |   |   |   |   |   |   |   |--- value: [0.26]
# |   |   |   |   |   |--- Cextractant (M) >  0.30
# |   |   |   |   |   |   |--- Cextractant (M) <= 0.35
# |   |   |   |   |   |   |   |--- Cacid (M) <= 2.03
# |   |   |   |   |   |   |   |   |--- value: [0.18]
# |   |   |   |   |   |   |   |--- Cacid (M) >  2.03
# |   |   |   |   |   |   |   |   |--- value: [0.23]
# |   |   |   |   |   |   |--- Cextractant (M) >  0.35
# |   |   |   |   |   |   |   |--- Cacid (M) <= 2.43
# |   |   |   |   |   |   |   |   |--- value: [0.27]
# |   |   |   |   |   |   |   |--- Cacid (M) >  2.43
# |   |   |   |   |   |   |   |   |--- value: [0.36]
# |   |   |   |--- Heterogeneity Index >  8.51
# |   |   |   |   |--- Cacid (M) <= 2.06
# |   |   |   |   |   |--- Cextractant (M) <= 0.92
# |   |   |   |   |   |   |--- Wiener <= 3594.00
# |   |   |   |   |   |   |   |--- Cacid (M) <= 2.00
# |   |   |   |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |   |   |   |--- Cacid (M) >  2.00
# |   |   |   |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |   |   |--- Wiener >  3594.00
# |   |   |   |   |   |   |   |--- Cextractant (M) <= 0.15
# |   |   |   |   |   |   |   |   |--- value: [0.03]
# |   |   |   |   |   |   |   |--- Cextractant (M) >  0.15
# |   |   |   |   |   |   |   |   |--- value: [0.11]
# |   |   |   |   |   |--- Cextractant (M) >  0.92
# |   |   |   |   |   |   |--- Cextractant (M) <= 1.65
# |   |   |   |   |   |   |   |--- Cacid (M) <= 2.00
# |   |   |   |   |   |   |   |   |--- value: [0.29]
# |   |   |   |   |   |   |   |--- Cacid (M) >  2.00
# |   |   |   |   |   |   |   |   |--- value: [0.35]
# |   |   |   |   |   |   |--- Cextractant (M) >  1.65
# |   |   |   |   |   |   |   |--- Cacid (M) <= 2.01
# |   |   |   |   |   |   |   |   |--- value: [0.03]
# |   |   |   |   |   |   |   |--- Cacid (M) >  2.01
# |   |   |   |   |   |   |   |   |--- value: [0.02]
# |   |   |   |   |--- Cacid (M) >  2.06
# |   |   |   |   |   |--- Cacid (M) <= 2.94
# |   |   |   |   |   |   |--- Wiener <= 6844.00
# |   |   |   |   |   |   |   |--- Cacid (M) <= 2.53
# |   |   |   |   |   |   |   |   |--- value: [0.01]
# |   |   |   |   |   |   |   |--- Cacid (M) >  2.53
# |   |   |   |   |   |   |   |   |--- value: [0.03]
# |   |   |   |   |   |   |--- Wiener >  6844.00
# |   |   |   |   |   |   |   |--- Cacid (M) <= 2.37
# |   |   |   |   |   |   |   |   |--- value: [0.08]
# |   |   |   |   |   |   |   |--- Cacid (M) >  2.37
# |   |   |   |   |   |   |   |   |--- value: [0.11]
# |   |   |   |   |   |--- Cacid (M) >  2.94
# |   |   |   |   |   |   |--- value: [0.20]
# |--- Cacid (M) >  2.97
# |   |--- Cacid (M) <= 9.33
# |   |   |--- Cacid (M) <= 6.97
# |   |   |   |--- Wiener <= 1303.00
# |   |   |   |   |--- Cextractant (M) <= 0.82
# |   |   |   |   |   |--- Cextractant (M) <= 0.72
# |   |   |   |   |   |   |--- Cextractant (M) <= 0.40
# |   |   |   |   |   |   |   |--- Cextractant (M) <= 0.15
# |   |   |   |   |   |   |   |   |--- value: [0.04]
# |   |   |   |   |   |   |   |--- Cextractant (M) >  0.15
# |   |   |   |   |   |   |   |   |--- value: [0.09]
# |   |   |   |   |   |   |--- Cextractant (M) >  0.40
# |   |   |   |   |   |   |   |--- Cextractant (M) <= 0.60
# |   |   |   |   |   |   |   |   |--- value: [0.21]
# |   |   |   |   |   |   |   |--- Cextractant (M) >  0.60
# |   |   |   |   |   |   |   |   |--- value: [0.27]
# |   |   |   |   |   |--- Cextractant (M) >  0.72
# |   |   |   |   |   |   |--- Cacid (M) <= 5.23
# |   |   |   |   |   |   |   |--- Cacid (M) <= 4.07
# |   |   |   |   |   |   |   |   |--- value: [0.01]
# |   |   |   |   |   |   |   |--- Cacid (M) >  4.07
# |   |   |   |   |   |   |   |   |--- value: [0.01]
# |   |   |   |   |   |   |--- Cacid (M) >  5.23
# |   |   |   |   |   |   |   |--- Cacid (M) <= 6.30
# |   |   |   |   |   |   |   |   |--- value: [0.03]
# |   |   |   |   |   |   |   |--- Cacid (M) >  6.30
# |   |   |   |   |   |   |   |   |--- value: [0.07]
# |   |   |   |   |--- Cextractant (M) >  0.82
# |   |   |   |   |   |--- Cextractant (M) <= 1.44
# |   |   |   |   |   |   |--- Cacid (M) <= 4.49
# |   |   |   |   |   |   |   |--- Cacid (M) <= 3.31
# |   |   |   |   |   |   |   |   |--- value: [0.48]
# |   |   |   |   |   |   |   |--- Cacid (M) >  3.31
# |   |   |   |   |   |   |   |   |--- value: [0.63]
# |   |   |   |   |   |   |--- Cacid (M) >  4.49
# |   |   |   |   |   |   |   |--- Cacid (M) <= 5.18
# |   |   |   |   |   |   |   |   |--- value: [0.76]
# |   |   |   |   |   |   |   |--- Cacid (M) >  5.18
# |   |   |   |   |   |   |   |   |--- value: [0.88]
# |   |   |   |   |   |--- Cextractant (M) >  1.44
# |   |   |   |   |   |   |--- Cacid (M) <= 3.12
# |   |   |   |   |   |   |   |--- Cextractant (M) <= 1.53
# |   |   |   |   |   |   |   |   |--- value: [0.03]
# |   |   |   |   |   |   |   |--- Cextractant (M) >  1.53
# |   |   |   |   |   |   |   |   |--- value: [0.66]
# |   |   |   |   |   |   |--- Cacid (M) >  3.12
# |   |   |   |   |   |   |   |--- Cacid (M) <= 5.49
# |   |   |   |   |   |   |   |   |--- value: [0.11]
# |   |   |   |   |   |   |   |--- Cacid (M) >  5.49
# |   |   |   |   |   |   |   |   |--- value: [0.28]
# |   |   |   |--- Wiener >  1303.00
# |   |   |   |   |--- Cextractant (M) <= 0.23
# |   |   |   |   |   |--- Cacid (M) <= 3.65
# |   |   |   |   |   |   |--- Cextractant (M) <= 0.18
# |   |   |   |   |   |   |   |--- Wiener <= 7388.00
# |   |   |   |   |   |   |   |   |--- value: [0.03]
# |   |   |   |   |   |   |   |--- Wiener >  7388.00
# |   |   |   |   |   |   |   |   |--- value: [0.12]
# |   |   |   |   |   |   |--- Cextractant (M) >  0.18
# |   |   |   |   |   |   |   |--- Cacid (M) <= 3.10
# |   |   |   |   |   |   |   |   |--- value: [0.16]
# |   |   |   |   |   |   |   |--- Cacid (M) >  3.10
# |   |   |   |   |   |   |   |   |--- value: [0.19]
# |   |   |   |   |   |--- Cacid (M) >  3.65
# |   |   |   |   |   |   |--- Cextractant (M) <= 0.12
# |   |   |   |   |   |   |   |--- Wiener <= 6844.00
# |   |   |   |   |   |   |   |   |--- value: [0.35]
# |   |   |   |   |   |   |   |--- Wiener >  6844.00
# |   |   |   |   |   |   |   |   |--- value: [0.17]
# |   |   |   |   |   |   |--- Cextractant (M) >  0.12
# |   |   |   |   |   |   |   |--- Cacid (M) <= 5.04
# |   |   |   |   |   |   |   |   |--- value: [0.24]
# |   |   |   |   |   |   |   |--- Cacid (M) >  5.04
# |   |   |   |   |   |   |   |   |--- value: [0.34]
# |   |   |   |   |--- Cextractant (M) >  0.23
# |   |   |   |   |   |--- Cextractant (M) <= 0.55
# |   |   |   |   |   |   |--- Cacid (M) <= 3.90
# |   |   |   |   |   |   |   |--- Cextractant (M) <= 0.40
# |   |   |   |   |   |   |   |   |--- value: [0.30]
# |   |   |   |   |   |   |   |--- Cextractant (M) >  0.40
# |   |   |   |   |   |   |   |   |--- value: [0.43]
# |   |   |   |   |   |   |--- Cacid (M) >  3.90
# |   |   |   |   |   |   |   |--- Cextractant (M) <= 0.35
# |   |   |   |   |   |   |   |   |--- value: [0.46]
# |   |   |   |   |   |   |   |--- Cextractant (M) >  0.35
# |   |   |   |   |   |   |   |   |--- value: [0.61]
# |   |   |   |   |   |--- Cextractant (M) >  0.55
# |   |   |   |   |   |   |--- Cacid (M) <= 5.50
# |   |   |   |   |   |   |   |--- Cacid (M) <= 2.99
# |   |   |   |   |   |   |   |   |--- value: [0.39]
# |   |   |   |   |   |   |   |--- Cacid (M) >  2.99
# |   |   |   |   |   |   |   |   |--- value: [0.80]
# |   |   |   |   |   |   |--- Cacid (M) >  5.50
# |   |   |   |   |   |   |   |--- Cextractant (M) <= 0.88
# |   |   |   |   |   |   |   |   |--- value: [1.04]
# |   |   |   |   |   |   |   |--- Cextractant (M) >  0.88
# |   |   |   |   |   |   |   |   |--- value: [1.30]
# |   |   |--- Cacid (M) >  6.97
# |   |   |   |--- Cacid (M) <= 7.06
# |   |   |   |   |--- Cacid (M) <= 7.03
# |   |   |   |   |   |--- Wiener <= 986.00
# |   |   |   |   |   |   |--- Cacid (M) <= 6.99
# |   |   |   |   |   |   |   |--- value: [0.95]
# |   |   |   |   |   |   |--- Cacid (M) >  6.99
# |   |   |   |   |   |   |   |--- Cacid (M) <= 7.00
# |   |   |   |   |   |   |   |   |--- value: [0.94]
# |   |   |   |   |   |   |   |--- Cacid (M) >  7.00
# |   |   |   |   |   |   |   |   |--- value: [0.94]
# |   |   |   |   |   |--- Wiener >  986.00
# |   |   |   |   |   |   |--- value: [0.46]
# |   |   |   |   |--- Cacid (M) >  7.03
# |   |   |   |   |   |--- value: [1.55]
# |   |   |   |--- Cacid (M) >  7.06
# |   |   |   |   |--- Cextractant (M) <= 0.15
# |   |   |   |   |   |--- Heterogeneity Index <= 8.51
# |   |   |   |   |   |   |--- Cacid (M) <= 7.97
# |   |   |   |   |   |   |   |--- Cacid (M) <= 7.15
# |   |   |   |   |   |   |   |   |--- value: [0.23]
# |   |   |   |   |   |   |   |--- Cacid (M) >  7.15
# |   |   |   |   |   |   |   |   |--- value: [0.23]
# |   |   |   |   |   |   |--- Cacid (M) >  7.97
# |   |   |   |   |   |   |   |--- Cacid (M) <= 8.61
# |   |   |   |   |   |   |   |   |--- value: [0.28]
# |   |   |   |   |   |   |   |--- Cacid (M) >  8.61
# |   |   |   |   |   |   |   |   |--- value: [0.24]
# |   |   |   |   |   |--- Heterogeneity Index >  8.51
# |   |   |   |   |   |   |--- value: [0.07]
# |   |   |   |   |--- Cextractant (M) >  0.15
# |   |   |   |   |   |--- Cacid (M) <= 7.80
# |   |   |   |   |   |   |--- Wiener <= 4455.00
# |   |   |   |   |   |   |   |--- Cextractant (M) <= 1.84
# |   |   |   |   |   |   |   |   |--- value: [0.24]
# |   |   |   |   |   |   |   |--- Cextractant (M) >  1.84
# |   |   |   |   |   |   |   |   |--- value: [0.52]
# |   |   |   |   |   |   |--- Wiener >  4455.00
# |   |   |   |   |   |   |   |--- Cextractant (M) <= 0.25
# |   |   |   |   |   |   |   |   |--- value: [0.44]
# |   |   |   |   |   |   |   |--- Cextractant (M) >  0.25
# |   |   |   |   |   |   |   |   |--- value: [0.66]
# |   |   |   |   |   |--- Cacid (M) >  7.80
# |   |   |   |   |   |   |--- Cextractant (M) <= 0.25
# |   |   |   |   |   |   |   |--- XlogP <= 9.35
# |   |   |   |   |   |   |   |   |--- value: [0.20]
# |   |   |   |   |   |   |   |--- XlogP >  9.35
# |   |   |   |   |   |   |   |   |--- value: [0.46]
# |   |   |   |   |   |   |--- Cextractant (M) >  0.25
# |   |   |   |   |   |   |   |--- Cacid (M) <= 7.94
# |   |   |   |   |   |   |   |   |--- value: [0.66]
# |   |   |   |   |   |   |   |--- Cacid (M) >  7.94
# |   |   |   |   |   |   |   |   |--- value: [0.87]
# |   |--- Cacid (M) >  9.33
# |   |   |--- Wiener <= 933.00
# |   |   |   |--- Cacid (M) <= 13.25
# |   |   |   |   |--- Cacid (M) <= 11.00
# |   |   |   |   |   |--- Cacid (M) <= 10.00
# |   |   |   |   |   |   |--- value: [1.07]
# |   |   |   |   |   |--- Cacid (M) >  10.00
# |   |   |   |   |   |   |--- Cacid (M) <= 10.00
# |   |   |   |   |   |   |   |--- value: [1.03]
# |   |   |   |   |   |   |--- Cacid (M) >  10.00
# |   |   |   |   |   |   |   |--- Cacid (M) <= 10.01
# |   |   |   |   |   |   |   |   |--- value: [1.06]
# |   |   |   |   |   |   |   |--- Cacid (M) >  10.01
# |   |   |   |   |   |   |   |   |--- value: [1.07]
# |   |   |   |   |--- Cacid (M) >  11.00
# |   |   |   |   |   |--- Cacid (M) <= 12.00
# |   |   |   |   |   |   |--- value: [1.14]
# |   |   |   |   |   |--- Cacid (M) >  12.00
# |   |   |   |   |   |   |--- Cacid (M) <= 12.01
# |   |   |   |   |   |   |   |--- value: [1.18]
# |   |   |   |   |   |   |--- Cacid (M) >  12.01
# |   |   |   |   |   |   |   |--- value: [1.19]
# |   |   |   |--- Cacid (M) >  13.25
# |   |   |   |   |--- Cacid (M) <= 14.50
# |   |   |   |   |   |--- value: [1.46]
# |   |   |   |   |--- Cacid (M) >  14.50
# |   |   |   |   |   |--- value: [1.48]
# |   |   |--- Wiener >  933.00
# |   |   |   |--- Wiener <= 7079.00
# |   |   |   |   |--- value: [0.21]
# |   |   |   |--- Wiener >  7079.00
# |   |   |   |   |--- Cacid (M) <= 13.05
# |   |   |   |   |   |--- Wiener <= 16524.00
# |   |   |   |   |   |   |--- value: [0.65]
# |   |   |   |   |   |--- Wiener >  16524.00
# |   |   |   |   |   |   |--- value: [0.65]
# |   |   |   |   |--- Cacid (M) >  13.05
# |   |   |   |   |   |--- value: [0.92]

# %%
plt.title('Cacid vs Cextractant train set')
plt.xlabel('Cacid (M)')
plt.ylabel('Cextractant (M)')
plt.scatter(X_trainset[:,1] ,X_trainset[:,0] , color='blue' , alpha=0.5, label='Train')
plt.scatter(X_testset[:, 1], X_testset[:, 0], color ='red', alpha=0.5, label='Test')
plt.legend()

# %%
#%matplotlib inline

#fnames=['ExtractantName', 'SolventName', 'AcidName', 'AverageAggregateSize (A)',
#       'has acid?', 'Cacid (M)', 'has ions?', 'xlogp', 'molecular_weight',
#       'h_bond_donor_count']
fig = plt.figure(figsize=(25,20))
plot = tree.plot_tree(myTree,
                   feature_names= feature_list,
                   class_names= ['Third phase', 'Biphasic'] ,
                   filled=True)
#fig.savefig("0decistion_tree.png")
#plot.show()

# %% [markdown]
# ___
# # RANDOM FLOREST
# ___

# %%
# Import the model we are using
from sklearn.ensemble import RandomForestRegressor
# Instantiate model with 1000 decision trees
#1000 42 give awesome results
rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)
# Train the model on training data
rf.fit(X_trainset, y_trainset)
# Out:
# RandomForestRegressor(n_estimators=1000, random_state=42)

# %%
# Use the forest's predict method on the train and test data
predictionsTrain = rf.predict(X_trainset)
predictions = rf.predict(X_testset)
# Calculate the absolute errors
errors = abs(predictions - y_testset)

plt.plot(y_testset, marker='+')
plt.plot(predictions, marker = 'o')
plt.show()

plt.xlabel("testset")
plt.ylabel("testset")
plt.scatter(y_testset, predictions)
plt.plot(y_testset, y_testset)
plt.title('#features: '+f"{100*len(y_testset)/(len(y_testset)+len(y_trainset)):.1f}"+'% of '+str(len(y))+' points)')
plt.show()

#now use some metrics to see how good are the predictions
print("DecisionTrees's R2: ", metrics.r2_score(y_testset,predictions))
print('Mean Absolute Error:', round(np.mean(errors), 5), 'M')
print('Mean Square Error:', metrics.mean_squared_error(y_testset, predictions)) #< (yreal-ypred)^2 >
print("Root mean square error:", np.sqrt(metrics.mean_squared_error(y_testset, predictions)))

#_____________________________

errors = abs(predictionsTrain - y_trainset)
plt.xlabel("Train set rows")
plt.ylabel("Train set")
plt.plot(y_trainset, marker='+')
plt.plot(predictionsTrain, marker = 'o')
plt.show()

plt.xlabel("CacidOrg (M)")
plt.ylabel("CacidOrg (M)")
plt.scatter(y_trainset, predictionsTrain)
plt.plot(y_trainset, y_trainset)
plt.title('#features: '+f"{100*len(y_trainset)/(len(y_testset)+len(y_trainset)):.1f}"+'% of '+str(len(y))+' points)')
plt.show()

#now use some metrics to see how good are the predictions
print("DecisionTrees's R2: ", metrics.r2_score(y_trainset,predictionsTrain))
print('Mean Absolute Error:', round(np.mean(y_trainset-predictionsTrain), 5), 'M')
print('Mean Square Error:', metrics.mean_squared_error(y_trainset, predictionsTrain)) #< (yreal-ypred)^2 >
print("Root mean square error:", np.sqrt(metrics.mean_squared_error(y_trainset, predictionsTrain)))
# Out:
# DecisionTrees's R2:  0.9608341913581746
# Mean Absolute Error: 0.01627 M
# Mean Square Error: 0.0015891209034882272
# Root mean square error: 0.0398637793427596
# DecisionTrees's R2:  0.9814805226885853
# Mean Absolute Error: 0.00021 M
# Mean Square Error: 0.0009353040071854969
# Root mean square error: 0.03058274034787427
